# %% [markdown]
# # The Movies Dataset - Data Cleaning and Analysis
#
# This notebook performs data cleaning and exploratory analysis on the MovieLens dataset.
#
# ## Project Structure
#
# - Raw data is stored in `data/raw/`.
# - Outputs (figures, processed data) are saved in `outputs/`.
# - Scripts for reusable code are in `src/`.

# %%
# Standard imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import missingno as msno
warnings.filterwarnings('ignore')

# %%
# Set data paths
DATA_DIR = '../data/raw/'
movies_metadata_path = DATA_DIR + 'movies_metadata.csv'
credits_path = DATA_DIR + 'credits.csv'
keywords_path = DATA_DIR + 'keywords.csv'
links_path = DATA_DIR + 'links.csv'
ratings_path = DATA_DIR + 'ratings.csv'
